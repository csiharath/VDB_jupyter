# %% [markdown]
# ## Objectifs
# ##### 1 Lire et traiter des données d'entrée avec [PANDAS](https://pandas.pydata.org/)
#
# ##### 2 Représenter la distribution empirique des "fold-change" (**FC**) vs Précision, aka: volcano-plot
#
# ##### 3 Effectuer une analyse de sur-représentation en termes GO
#
#
# ## Ressources : Rappels et illustration de l'analyse de représentation de termes GO
# ###### [TP de MADP](https://github.com/glaunay/tp-proteomics#3-obtention-des-param%C3%A8tres-du-mod%C3%A8le)
# ###### [Fiche Bioconductor](https://www.bioconductor.org/help/course-materials/2015/SeattleApr2015/E_GeneSetEnrichment.html)

# %% [markdown]
# ### Préparation de  l'environnement
#
# ##### Please `pip install -r requirements.txt` first
#
# ##### Directory Configuration
#
# * `workDir` points to the Git project, holds the *tsv* file
# * `libDir` points to Git project subdirectory hosting python library with files names `go.py  stat_utils.py  uniprot.py`
# * `dataDir` points to the data folder with uniprot and GO files

# %%
import sys, os
workDir = f"{os.getcwd()}/.."
libDir = f"{workDir}/lib"
dataDir= f"{workDir}/data" 

sys.path.append(libDir)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas
import numpy as np

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Jeux de données
# * Jeux de données de protéomique quantitative au format TSV
# * Ontologie GO au format [owl](http://www.obofoundry.org/ontology/go.html)
# * Entrées Uniprot au format XML
#     * Protéines de l'étude
#     * Protéome d'E.Coli complet
#
# <hr style="border:1px solid gray"> </hr>

# %% [markdown]
# ### Lecture des valeurs experimentales
# Charger ```TCL_wt1.tsv``` dans une [dataframe pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html).
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$
# Retirer les lignes présentant des aberrations numériques
# </span>
# <br/><span style="color:firebrick;font-weight:bold">$\rhd$ Attention aux types des colonnes !</span>

# %%
df = pandas.read_csv("../TCL_wt1.tsv", sep="\t", na_values="#VALEUR!", dtype={'Corrected Abundance ratio (1.53)':np.float64, 'Log2 Corrected Abundance Ratio':np.float64,'Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)':np.float64, 'LOG10 Adj.P-val':np.float64})
df = df.dropna()
df
# Out:
#      Accession                                        Description Gene Symbol  \
# 0       P75936  Basal-body rod modification protein FlgD OS=Es...        flgD
# 1       P76231  Uncharacterized protein YeaC OS=Escherichia co...        yeaC
# 2       P0A8S9  Flagellar transcriptional regulator FlhD OS=Es...        flhD
# 4       P05706  PTS system glucitol/sorbitol-specific EIIA com...        srlB
# 5       P29744  Flagellar hook-associated protein 3 OS=Escheri...        flgL
# ...        ...                                                ...         ...
# 2011    P77330  Prophage lipoprotein Bor homolog OS=Escherichi...        borD
# 2016    P02930  Outer membrane protein TolC OS=Escherichia col...        tolC
# 2020    P0A917  Outer membrane protein X OS=Escherichia coli (...        ompX
# 2021    P02931  Outer membrane protein F OS=Escherichia coli (...        ompF
# 2022    P0AB40  Multiple stress resistance protein BhsA OS=Esc...        bhsA
#
#       Corrected Abundance ratio (1.53)  Log2 Corrected Abundance Ratio  \
# 0                             0.075817                       -3.721335
# 1                             0.092810                       -3.429569
# 2                             0.102614                       -3.284695
# 4                             0.108497                       -3.204277
# 5                             0.124183                       -3.009460
# ...                                ...                             ...
# 2011                          1.535948                        0.619129
# 2016                          1.552288                        0.634396
# 2020                          1.579739                        0.659686
# 2021                          1.754902                        0.811390
# 2022                          1.798039                        0.846424
#
#       Abundance Ratio Adj. P-Value: (127. T3 Tc WT) / (126. T0 WT)  \
# 0                                              0.000055
# 1                                              0.000351
# 2                                              0.000027
# 4                                              0.019963
# 5                                              0.036746
# ...                                                 ...
# 2011                                           0.310725
# 2016                                           0.013373
# 2020                                           0.002226
# 2021                                           0.000068
# 2022                                           0.035928
#
#       LOG10 Adj.P-val
# 0            4.260067
# 1            3.454627
# 2            4.571899
# 4            1.699768
# 5            1.434787
# ...               ...
# 2011         0.507623
# 2016         1.873757
# 2020         2.652391
# 2021         4.164956
# 2022         1.444561
#
# [1746 rows x 7 columns]

# %% [markdown]
# ##### 1. Un premier volcano-plot
#
# Ce type de figure représente pour chaque protéine en abscisse le taux d'abondance et en ordonnée la précision de la mesure.
#
# <span style="color:firebrick;font-weight:bold">$\rhd$ 1. Réaliser un scatter plot matplotlib avec</span>
# <br/><span style="color:firebrick;font-weight:bold">- en x, `Log2 Corrected Abundance Ratio`</span>
# <br/><span style="color:firebrick;font-weight:bold">-  en y, `LOG10 Adj.P-val`</span>
#
# <span style="color:firebrick;font-weight:bold">$\rhd$Vous légenderez les axes, attention `LOG10 Adj.P-val` est en fait `-LOG10 Adj.P-val`, regardez bien.</span>

# %% [markdown]
# ##### 2. Réaliser des versions évoluées du graphique précédent
# L'objectif est de mettre l'accent sur la région **-Log10 adj Pvalue > 4** et **Log2 corrected abundance ratio > 0**.
# <br/>Pour cela vous revisiterez le scatter plot précedent au travers des versions suivantes:
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ première version : un rectangle de la couleur de votre choix matérialisera la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ deuxième version  : une couleur de votre choix représentera les points de la région</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ troisème version (optionnel): Les identifiants uniprot remplaceront les points des protéines de la région</span>

# %%
CAR = df["Log2 Corrected Abundance Ratio"]
APV = df["LOG10 Adj.P-val"]
ID = df["Accession"]

# %%
fig1, f1_ax = plt.subplots(figsize=(8,6), ncols=1, nrows=1)

f1_ax.scatter(CAR, APV, color="#4C6793")
f1_ax.set_xlabel("Log2 Corrected Abundance Ratio")
f1_ax.set_ylabel("-LOG10 Adj.P-val")
# Out:
# Text(0, 0.5, '-LOG10 Adj.P-val')

# %%
rect = matplotlib.patches.Rectangle((0,4), 1, 4, alpha=0.5, color="#F96666")

fig2, f2_ax = plt.subplots(figsize=(8,6), ncols=1, nrows=1)

f2_ax.scatter(CAR, APV, color="#4C6793")
f2_ax.set_xlabel("Log2 Corrected Abundance Ratio")
f2_ax.set_ylabel("-LOG10 Adj.P-val")
f2_ax.add_patch(rect)

# %%
col = np.where(CAR<0,"#4C6793",np.where(APV<4,"#4C6793",'#F96666'))

fig3, f3_ax = plt.subplots(figsize=(8,6), ncols=1, nrows=1)

f3_ax.scatter(CAR, APV, color=col)
f3_ax.set_xlabel("Log2 Corrected Abundance Ratio")
f3_ax.set_ylabel("-LOG10 Adj.P-val")
# Out:
# Text(0, 0.5, '-LOG10 Adj.P-val')

# %%
mark = np.where(CAR<0,"o",np.where(APV<4,"o",ID))
m = matplotlib.markers.MarkerStyle(mark)

fig4, f4_ax = plt.subplots(figsize=(8,6), ncols=1, nrows=1)

f4_ax.scatter(CAR, APV, color=col, marker=m)
f4_ax.set_xlabel("Log2 Corrected Abundance Ratio")
f4_ax.set_ylabel("-LOG10 Adj.P-val")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\VDB\lib\site-packages\matplotlib\markers.py:359, in MarkerStyle._set_marker(self, marker)
#     358 try:
# --> 359     Path(marker)
#     360     self._marker_function = self._set_vertices
#
# File ~\anaconda3\envs\VDB\lib\site-packages\matplotlib\path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File ~\anaconda3\envs\VDB\lib\site-packages\matplotlib\cbook\__init__.py:1369, in _to_unmasked_float_array(x)
#    1368 else:
# -> 1369     return np.asarray(x, float)
#
# ValueError: could not convert string to float: 'o'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [107], line 2
#       1 mark = np.where(CAR<0,"o",np.where(APV<4,"o",ID))
# ----> 2 m = matplotlib.markers.MarkerStyle(mark)
#       4 fig4, f4_ax = plt.subplots(figsize=(8,6), ncols=1, nrows=1)
#       6 f4_ax.scatter(CAR, APV, color=col, marker=m)
#
# File ~\anaconda3\envs\VDB\lib\site-packages\matplotlib\markers.py:272, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     267     marker = ""
#     268     _api.warn_deprecated(
#     269         "3.6", message="MarkerStyle(None) is deprecated since "
#     270         "%(since)s; support will be removed %(removal)s.  Use "
#     271         "MarkerStyle('') to construct an empty MarkerStyle.")
# --> 272 self._set_marker(marker)
#
# File ~\anaconda3\envs\VDB\lib\site-packages\matplotlib\markers.py:362, in MarkerStyle._set_marker(self, marker)
#     360         self._marker_function = self._set_vertices
#     361     except ValueError as err:
# --> 362         raise ValueError('Unrecognized marker style {!r}'
#     363                          .format(marker)) from err
#     365 if not isinstance(marker, MarkerStyle):
#     366     self._marker = marker
#
# ValueError: Unrecognized marker style array(['o', 'o', 'o', ..., 'o', 'P02931', 'o'], dtype=object)

# %% [markdown]
# #### Analyse ORA
#
# ##### Principes
# Vous disposez d'un objet analyser permettant de réaliser une analyse de la sur-représentation (**ORA**) en termes GO parmi une liste de protéine d'intérêt.
# La fréquence des termes GO dans le protéome totale est utilisée comme référence.
#
# L'objet analyser s'instancie ainsi
# ```python
# from stat_utils import GO_ORA_analyser
# o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# ```
#
# Il fournit une méthode pour chaque catégorie de termes GO
# <i>{ biological_process, molecular_function, cellular_component }</i>
#
# Une éventuelle surreprésentation des termes GO de la catégorie <i>biological_process</i> est par exemple calculée parmi les protéines P29744 et P05706 de la façon suivante:
#
# ```python
# goTerm_scores = o.biological_process(["P29744", "P05706"])
# ```
# <span style="color:green;font-weight:bold">$\uparrow$ Reproduire cet exemple dans la cellule ci-dessous.$\downarrow$ </span>
# </br><span style="color:firebrick;font-weight:bold"> $\rhd$ Inspecter l'objet retourné par la méthode o.biological_process, que voyez-vous ?</span>

# %%
from stat_utils import GO_ORA_analyser
o = GO_ORA_analyser(f"{dataDir}/go.owl", f"{dataDir}/K12_proteome", f"{dataDir}/dataset")
# Out:
# Loading ontology
# Loaded
# Reading whole proteome
# 4391 Loaded
# reading experimental protein set
# 2024 Loaded

# %%
o.biological_process
# Out:
# <bound method GO_ORA_analyser.biological_process of <stat_utils.GO_ORA_analyser object at 0x00000229751CF0D0>>

# %% [markdown]
# ###### 2/ Analyser la représentation des termes GO parmi les protéines surabondantes de l'experience
# <span style="color:firebrick;font-weight:bold"> $\rhd$ Vous devrez extraire les identifiants uniprot des protéines aux `Log2 Corrected Abundance Ratio` supérieurs au seuil alpha de 5%.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous conduirez sur cette liste de protéines une analyse de sur-représentation en termes GO à l'aide d'un objet *GO_ORA_analyser*.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous pouvez faire varier le seuil d'abondance autour de la valeur alpha.</span>
# <br/><span style="color:firebrick;font-weight:bold"> $\rhd$ Vous traiterez les 3 catégories *biological_process / molecular_function /cellular_component*.</span>
#
#
#
# Familiarisez-vous avec la structures des dictionnaires de résultas, vous pouvez [les sauvegarder au format json](https://docs.python.org/3/library/json.html).

# %%
alpha = -0.096

l_go = [prot["Accession"] for index, prot in df.iterrows() if prot[4] > alpha]
# df.loc["Log2 Corrected Abundance Ratio">=alpha]["Accession"].to_list()
len(l_go)
# Out:
# 67

# %%
bp = o.biological_process(l_go)
# Out:
# Building biological process GO Tree
# Extracting biological process ontology
# Applying true path collapsing
# 389 GO terms, 105 leaves, 53 proteins
# Extracting biological process ontology
# Applying true path collapsing
# 2728 GO terms, 6650 leaves, 3128 proteins
# Evaluated 388 / 388 Pathways, based on 67 proteins

# %%
bp_sort = sorted(bp, key=lambda prot:prot[0])
bp_sort
# Out:
# [(2.4384924031076443e-05,
#   'siderophore transport',
#   'GO:0015891',
#   ['P13036', 'P06971', 'P75780', 'P02930', 'P05825']),
#  (5.561766370326049e-05,
#   'ion transport',
#   'GO:0006811',
#   ['P02943',
#    'P0A927',
#    'P0A910',
#    'P0AG78',
#    'P0AFJ5',
#    'P23173',
#    'P0AER8',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P77338',
#    'P0AB98',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931']),
#  (0.0001096983582129087,
#   'iron coordination entity transport',
#   'GO:1901678',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']),
#  (0.0001517600944958151,
#   'protein insertion into membrane',
#   'GO:0051205',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.0002376596372987538,
#   'membrane organization',
#   'GO:0061024',
#   ['P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506']),
#  (0.00026730749824558384,
#   'Gram-negative-bacterium-type cell outer membrane assembly',
#   'GO:0043165',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.00026730749824558384,
#   'membrane assembly',
#   'GO:0071709',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.0003440562569104042,
#   'establishment of protein localization to membrane',
#   'GO:0090150',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.0009106481040647094,
#   'iron ion transport',
#   'GO:0006826',
#   ['P13036', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780', 'P02930']),
#  (0.001029678690889067,
#   'establishment of localization',
#   'GO:0051234',
#   ['P02943',
#    'P0A927',
#    'P0A910',
#    'P0AG78',
#    'P0AFJ5',
#    'P23173',
#    'P0AER8',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P77338',
#    'P0AB98',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P77338',
#    'P0AGI1',
#    'P02931',
#    'P02943',
#    'P0ADE4',
#    'P05825',
#    'P75780',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (0.0030544720005266073,
#   'translation',
#   'GO:0006412',
#   ['P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.003524298545195742,
#   'localization',
#   'GO:0051179',
#   ['P02943',
#    'P0A927',
#    'P0A910',
#    'P0AG78',
#    'P0AFJ5',
#    'P23173',
#    'P0AER8',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P77338',
#    'P0AB98',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P77338',
#    'P0AGI1',
#    'P02931',
#    'P02943',
#    'P0ADE4',
#    'P05825',
#    'P75780',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (0.0035775184651053848,
#   'ribonucleoprotein complex biogenesis',
#   'GO:0022613',
#   ['P0AB28', 'P60390', 'P0A7G2', 'P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.0035775184651053848,
#   'ribosome biogenesis',
#   'GO:0042254',
#   ['P0AB28', 'P60390', 'P0A7G2', 'P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.0036458270107751403,
#   'cellular protein localization',
#   'GO:0034613',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.0036458270107751403,
#   'cellular macromolecule localization',
#   'GO:0070727',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937']),
#  (0.003911683388498183,
#   'cellular localization',
#   'GO:0051641',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937', 'P05825', 'P05825']),
#  (0.004164563090996108,
#   'phospholipid transport',
#   'GO:0015914',
#   ['P06996', 'P76506']),
#  (0.004167624043539427,
#   'macromolecule localization',
#   'GO:0033036',
#   ['P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P0ADE4',
#    'P02943',
#    'P06996',
#    'P76506']),
#  (0.005187046033618788,
#   'peptide biosynthetic process',
#   'GO:0043043',
#   ['P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.00653842955812019,
#   'amide biosynthetic process',
#   'GO:0043604',
#   ['P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.007258368952379507,
#   'cellular component biogenesis',
#   'GO:0044085',
#   ['P0AB52',
#    'P02931',
#    'P0A7M6',
#    'P68919',
#    'P62399',
#    'P0A7T3',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P0AB28',
#    'P60390',
#    'P0A7G2',
#    'P0A908']),
#  (0.008159745328344918,
#   'homeostatic process',
#   'GO:0042592',
#   ['P77338', 'P05825', 'P05825', 'P0AC69', 'P13036', 'P06971', 'P75780']),
#  (0.008404316193228598,
#   'iron ion homeostasis',
#   'GO:0055072',
#   ['P13036', 'P06971', 'P75780', 'P05825', 'P05825']),
#  (0.008430018524370801,
#   'chemical homeostasis',
#   'GO:0048878',
#   ['P77338', 'P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.008655436643014434,
#   'peptide metabolic process',
#   'GO:0006518',
#   ['P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.010154292232116663,
#   'metal ion transport',
#   'GO:0030001',
#   ['P77338',
#    'P13036',
#    'P05825',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P02930']),
#  (0.014199761382963624,
#   'enterobactin transport',
#   'GO:0042930',
#   ['P02930', 'P05825']),
#  (0.014615075347119175,
#   'cofactor transport',
#   'GO:0051181',
#   ['P02930', 'P05825', 'P06129']),
#  (0.014807502494221468,
#   'ion transmembrane transport',
#   'GO:0034220',
#   ['P0A910', 'P06129', 'P02930', 'P02931', 'P23173', 'P0AER8', 'P0AB98']),
#  (0.014943417033422737,
#   'transition metal ion homeostasis',
#   'GO:0055076',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.01608034993378757,
#   'metal ion homeostasis',
#   'GO:0055065',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.016448610863797765,
#   'anion transport',
#   'GO:0006820',
#   ['P0AG78',
#    'P0AFJ5',
#    'P23173',
#    'P0AER8',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506']),
#  (0.01925803103396856,
#   'cellular amide metabolic process',
#   'GO:0043603',
#   ['P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.019669182796493125,
#   'transport',
#   'GO:0006810',
#   ['P02943',
#    'P0A927',
#    'P0A910',
#    'P0AG78',
#    'P0AFJ5',
#    'P23173',
#    'P0AER8',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P77338',
#    'P0AB98',
#    'P13036',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P77338',
#    'P0AGI1',
#    'P02931',
#    'P02943',
#    'P0ADE4',
#    'P05825',
#    'P75780',
#    'P0A927',
#    'P06129',
#    'P02930']),
#  (0.02097683155917345,
#   'co-translational protein modification',
#   'GO:0043686',
#   ['P0A6K3']),
#  (0.02097683155917345, 'detection of virus', 'GO:0009597', ['P0A910']),
#  (0.02116679961484097,
#   'ribonucleoprotein complex assembly',
#   'GO:0022618',
#   ['P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.02116679961484097,
#   'ribosome assembly',
#   'GO:0042255',
#   ['P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.0218780125076277,
#   'ribosomal large subunit assembly',
#   'GO:0000027',
#   ['P0A7M6', 'P68919', 'P62399']),
#  (0.0218780125076277,
#   'ribosomal large subunit biogenesis',
#   'GO:0042273',
#   ['P0A7M6', 'P68919', 'P62399']),
#  (0.023565743488627902,
#   'protein metabolic process',
#   'GO:0019538',
#   ['P60955',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P23894',
#    'P09169']),
#  (0.024576115578106034,
#   'cellular component assembly',
#   'GO:0022607',
#   ['P0AB52',
#    'P02931',
#    'P0A7M6',
#    'P68919',
#    'P62399',
#    'P0A7T3',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937']),
#  (0.028781610533363543,
#   'cation homeostasis',
#   'GO:0055080',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.029142322519184277,
#   'cellular component organization or biogenesis',
#   'GO:0071840',
#   ['P0AB52',
#    'P02931',
#    'P0A7M6',
#    'P68919',
#    'P62399',
#    'P0A7T3',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P77338',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P0AB28',
#    'P60390',
#    'P0A7G2',
#    'P0A908']),
#  (0.030476808932900168,
#   'ion homeostasis',
#   'GO:0050801',
#   ['P05825', 'P05825', 'P13036', 'P06971', 'P75780']),
#  (0.03355342484871182,
#   'viral entry into host cell',
#   'GO:0046718',
#   ['P0A927', 'P0A910']),
#  (0.04152006747697345,
#   'plasma membrane ATP synthesis coupled proton transport',
#   'GO:0042777',
#   ['P0AB98']),
#  (0.04152006747697345,
#   'tryptophan catabolic process',
#   'GO:0006569',
#   ['P23173']),
#  (0.04152006747697345,
#   'indolalkylamine catabolic process',
#   'GO:0046218',
#   ['P23173']),
#  (0.04152006747697345,
#   'indole-containing compound catabolic process',
#   'GO:0042436',
#   ['P23173']),
#  (0.04152006747697345, 'fatty acid elongation', 'GO:0030497', ['P0AEK2']),
#  (0.04152006747697345,
#   'cellular response to zinc ion starvation',
#   'GO:0034224',
#   ['P76344']),
#  (0.04152006747697345,
#   'cellular response to magnesium ion',
#   'GO:0071286',
#   ['P77330']),
#  (0.04152006747697345,
#   'intermembrane phospholipid transfer',
#   'GO:0120010',
#   ['P76506']),
#  (0.04152006747697345, 'colicin transport', 'GO:0042914', ['P05825']),
#  (0.0494580998553971,
#   'establishment of protein localization',
#   'GO:0045184',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937', 'P0ADE4']),
#  (0.05132385355362359,
#   'protein localization',
#   'GO:0008104',
#   ['P0A903', 'P77774', 'P0A940', 'P0A937', 'P0ADE4']),
#  (0.052999792006237945,
#   'drug transport',
#   'GO:0015893',
#   ['P02931', 'P0AER8', 'P06129', 'P02930']),
#  (0.06163853723857831,
#   'base-excision repair, AP site formation',
#   'GO:0006285',
#   ['P0A9H1']),
#  (0.06163853723857831, 'maturation of SSU-rRNA', 'GO:0030490', ['P0A7G2']),
#  (0.06163853723857831,
#   'L-proline biosynthetic process',
#   'GO:0055129',
#   ['P0A9L8']),
#  (0.06163853723857831, 'cellular water homeostasis', 'GO:0009992', ['P77338']),
#  (0.06163853723857831, 'conjugation', 'GO:0000746', ['P0A910']),
#  (0.06163853723857831,
#   'L-glutamate transmembrane transport',
#   'GO:0015813',
#   ['P0AER8']),
#  (0.06163853723857831,
#   'D-ribose transmembrane transport',
#   'GO:0015752',
#   ['P0AGI1']),
#  (0.06163853723857831,
#   'response to organic cyclic compound',
#   'GO:0014070',
#   ['P02930']),
#  (0.06465722151175946, 'lipid transport', 'GO:0006869', ['P06996', 'P76506']),
#  (0.06558699152618325,
#   'organelle assembly',
#   'GO:0070925',
#   ['P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.0657671241625898,
#   'organic anion transport',
#   'GO:0015711',
#   ['P23173', 'P0AER8', 'P02930', 'P05825', 'P06996', 'P76506']),
#  (0.07051971441355599,
#   'inorganic anion transport',
#   'GO:0015698',
#   ['P0AG78', 'P0AFJ5']),
#  (0.07595533802386038,
#   'cellular protein metabolic process',
#   'GO:0044267',
#   ['P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3']),
#  (0.07654919225661269,
#   'ribosomal small subunit biogenesis',
#   'GO:0042274',
#   ['P0A7T3', 'P0A7G2']),
#  (0.07741793108631193,
#   'cation transport',
#   'GO:0006812',
#   ['P77338',
#    'P0AB98',
#    'P13036',
#    'P05825',
#    'P05825',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P02930']),
#  (0.07830565258108657,
#   'response to metal ion',
#   'GO:0010038',
#   ['P76344', 'P77330', 'P0AB40']),
#  (0.08134089324140353,
#   'aromatic amino acid family catabolic process',
#   'GO:0009074',
#   ['P23173']),
#  (0.08134089324140353,
#   'proline biosynthetic process',
#   'GO:0006561',
#   ['P0A9L8']),
#  (0.08134089324140353,
#   'lipoprotein biosynthetic process',
#   'GO:0042158',
#   ['P60955']),
#  (0.08134089324140353, 'proline metabolic process', 'GO:0006560', ['P0A9L8']),
#  (0.08134089324140353, 'cell volume homeostasis', 'GO:0006884', ['P77338']),
#  (0.08134089324140353,
#   'negative regulation of single-species biofilm formation on inanimate substrate',
#   'GO:1900232',
#   ['P0ACF8']),
#  (0.08134089324140353, 'sulfate transport', 'GO:0008272', ['P0AG78']),
#  (0.08134089324140353,
#   'intermembrane lipid transfer',
#   'GO:0120009',
#   ['P76506']),
#  (0.08134089324140353, 'drug export', 'GO:0046618', ['P02930']),
#  (0.08134089324140353, 'response to cadmium ion', 'GO:0046686', ['P76344']),
#  (0.08134089324140353,
#   'regulation of cellular component size',
#   'GO:0032535',
#   ['P77338']),
#  (0.08134089324140353, 'regulation of cell size', 'GO:0008361', ['P77338']),
#  (0.0827363088335038,
#   'interaction with host',
#   'GO:0051701',
#   ['P0A927', 'P0A910']),
#  (0.10063561429244613,
#   'N-terminal protein amino acid modification',
#   'GO:0031365',
#   ['P0A6K3']),
#  (0.10063561429244613,
#   'negative regulation of single-species biofilm formation',
#   'GO:1900191',
#   ['P0ACF8']),
#  (0.10063561429244613, 'maltodextrin transport', 'GO:0042956', ['P02943']),
#  (0.10063561429244613, 'cobalamin transport', 'GO:0015889', ['P06129']),
#  (0.10063561429244613,
#   'negative regulation of multi-organism process',
#   'GO:0043901',
#   ['P0ACF8']),
#  (0.10702843131038686,
#   'protein-containing complex assembly',
#   'GO:0065003',
#   ['P0AB52', 'P02931', 'P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.11953100903763461,
#   'ferric-enterobactin import into cell',
#   'GO:0015685',
#   ['P05825']),
#  (0.11953100903763461, 'nucleoside transport', 'GO:0015858', ['P0A927']),
#  (0.11953100903763461, 'polysaccharide transport', 'GO:0015774', ['P02943']),
#  (0.12748279126894269,
#   'organic substance transport',
#   'GO:0071702',
#   ['P23173',
#    'P0AER8',
#    'P02930',
#    'P05825',
#    'P06996',
#    'P76506',
#    'P0AGI1',
#    'P02943',
#    'P0ADE4',
#    'P05825',
#    'P75780',
#    'P0A927',
#    'P06129']),
#  (0.136884590484858, 'symbiotic process', 'GO:0044403', ['P0A927', 'P0A910']),
#  (0.13803521932448487, 'protein homotrimerization', 'GO:0070207', ['P02931']),
#  (0.13803521932448487,
#   'regulation of single-species biofilm formation on inanimate substrate',
#   'GO:1900231',
#   ['P0ACF8']),
#  (0.13803521932448487, 'microcin transport', 'GO:0042884', ['P75780']),
#  (0.1514312695952313,
#   'amino acid transmembrane transport',
#   'GO:0003333',
#   ['P23173', 'P0AER8']),
#  (0.15615622349933875, 'uracil catabolic process', 'GO:0006212', ['P39831']),
#  (0.15615622349933875,
#   'ATP synthesis coupled proton transport',
#   'GO:0015986',
#   ['P0AB98']),
#  (0.15615622349933875, 'protein hexamerization', 'GO:0034214', ['P0AB52']),
#  (0.1607952233685761,
#   'cellular component organization',
#   'GO:0016043',
#   ['P0AB52',
#    'P02931',
#    'P0A7M6',
#    'P68919',
#    'P62399',
#    'P0A7T3',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P77338',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506']),
#  (0.1647634194049047,
#   'transmembrane transport',
#   'GO:0055085',
#   ['P77338',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P23173',
#    'P0AER8',
#    'P0AB98',
#    'P0AGI1',
#    'P02931']),
#  (0.17004918266509553,
#   'cellular homeostasis',
#   'GO:0019725',
#   ['P77338', 'P05825', 'P05825', 'P0AC69']),
#  (0.17378699054046556,
#   'interspecies interaction between organisms',
#   'GO:0044419',
#   ['P0A927', 'P0A910']),
#  (0.1739018396404386, 'ATP biosynthetic process', 'GO:0006754', ['P0AB98']),
#  (0.1739018396404386,
#   'indole-containing compound metabolic process',
#   'GO:0042430',
#   ['P23173']),
#  (0.1739018396404386,
#   'indolalkylamine metabolic process',
#   'GO:0006586',
#   ['P23173']),
#  (0.1739018396404386,
#   'tryptophan metabolic process',
#   'GO:0006568',
#   ['P23173']),
#  (0.1739018396404386, 'uracil metabolic process', 'GO:0019860', ['P39831']),
#  (0.1739018396404386,
#   'siderophore-dependent iron import into cell',
#   'GO:0033214',
#   ['P05825', 'P05825']),
#  (0.18073370876630576,
#   'protein-containing complex subunit organization',
#   'GO:0043933',
#   ['P0AB52', 'P02931', 'P0A7M6', 'P68919', 'P62399', 'P0A7T3']),
#  (0.19127972872806517,
#   'purine ribonucleoside triphosphate biosynthetic process',
#   'GO:0009206',
#   ['P0AB98']),
#  (0.19127972872806517,
#   'purine nucleoside triphosphate biosynthetic process',
#   'GO:0009145',
#   ['P0AB98']),
#  (0.19127972872806517,
#   'purine ribonucleoside triphosphate metabolic process',
#   'GO:0009205',
#   ['P0AB98']),
#  (0.19127972872806517,
#   'biotin biosynthetic process',
#   'GO:0009102',
#   ['P0AEK2']),
#  (0.19127972872806517, 'biotin metabolic process', 'GO:0006768', ['P0AEK2']),
#  (0.19127972872806517, 'base-excision repair', 'GO:0006284', ['P0A9H1']),
#  (0.19127972872806517, 'phosphate ion transport', 'GO:0006817', ['P0AFJ5']),
#  (0.19127972872806517,
#   'nucleobase-containing compound transport',
#   'GO:0015931',
#   ['P0A927']),
#  (0.19664405847937066, 'proteolysis', 'GO:0006508', ['P23894', 'P09169']),
#  (0.19688395529192979,
#   'regulation of biological quality',
#   'GO:0065008',
#   ['P77338', 'P05825', 'P05825', 'P0AC69', 'P13036', 'P06971', 'P75780']),
#  (0.2082973977529457,
#   'pentose transmembrane transport',
#   'GO:0015750',
#   ['P0AGI1']),
#  (0.2109127895365341,
#   'organonitrogen compound biosynthetic process',
#   'GO:1901566',
#   ['P60955',
#    'P0AEK2',
#    'P0AB98',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A9L8',
#    'P0A908']),
#  (0.2198585745809485, 'rRNA processing', 'GO:0006364', ['P60390', 'P0A7G2']),
#  (0.22496220276411527,
#   'pyrimidine nucleobase catabolic process',
#   'GO:0006208',
#   ['P39831']),
#  (0.22496220276411527,
#   'purine nucleoside triphosphate metabolic process',
#   'GO:0009144',
#   ['P0AB98']),
#  (0.22496220276411527, 'protein repair', 'GO:0030091', ['P0A7A5']),
#  (0.23546943512817747,
#   'cellular chemical homeostasis',
#   'GO:0055082',
#   ['P77338', 'P05825', 'P05825']),
#  (0.23546943512817747,
#   'drug transmembrane transport',
#   'GO:0006855',
#   ['P02931', 'P0AER8']),
#  (0.24128135185739122,
#   'ribonucleoside triphosphate metabolic process',
#   'GO:0009199',
#   ['P0AB98']),
#  (0.24128135185739122,
#   'ribonucleoside triphosphate biosynthetic process',
#   'GO:0009201',
#   ['P0AB98']),
#  (0.24332432945117996,
#   'nitrogen compound transport',
#   'GO:0071705',
#   ['P23173', 'P0AER8', 'P0ADE4', 'P05825', 'P75780', 'P0A927', 'P06129']),
#  (0.2465124836567832,
#   'response to inorganic substance',
#   'GO:0010035',
#   ['P76344', 'P77330', 'P0AB40']),
#  (0.25114718508077993,
#   'carboxylic acid transmembrane transport',
#   'GO:1905039',
#   ['P23173', 'P0AER8']),
#  (0.25114718508077993,
#   'organic acid transmembrane transport',
#   'GO:1903825',
#   ['P23173', 'P0AER8']),
#  (0.25726190810560073,
#   'regulation of single-species biofilm formation',
#   'GO:1900190',
#   ['P0ACF8']),
#  (0.25726190810560073,
#   'regulation of multi-organism process',
#   'GO:0043900',
#   ['P0ACF8']),
#  (0.27291079243167765,
#   'single-species biofilm formation on inanimate substrate',
#   'GO:0044011',
#   ['P0ACF8']),
#  (0.27291079243167765,
#   'iron import into cell',
#   'GO:0033212',
#   ['P05825', 'P05825']),
#  (0.27291079243167765,
#   'cellular response to metal ion',
#   'GO:0071248',
#   ['P77330']),
#  (0.27291079243167765, 'response to copper ion', 'GO:0046688', ['P0AB40']),
#  (0.28823478642572564,
#   'nucleoside triphosphate biosynthetic process',
#   'GO:0009142',
#   ['P0AB98']),
#  (0.30324053510712146,
#   'ribosomal small subunit assembly',
#   'GO:0000028',
#   ['P0A7T3']),
#  (0.3061066878001291,
#   'regulation of translation',
#   'GO:0006417',
#   ['P0ACF8', 'P68919']),
#  (0.3061066878001291,
#   'regulation of cellular amide metabolic process',
#   'GO:0034248',
#   ['P0ACF8', 'P68919']),
#  (0.31392425780407224,
#   'monovalent inorganic cation transport',
#   'GO:0015672',
#   ['P77338', 'P0AB98']),
#  (0.3179345496327187,
#   'L-alpha-amino acid transmembrane transport',
#   'GO:1902475',
#   ['P0AER8']),
#  (0.3179345496327187, 'response to cold', 'GO:0009409', ['P0A7G2']),
#  (0.3179345496327187,
#   'cellular response to inorganic substance',
#   'GO:0071241',
#   ['P77330']),
#  (0.3179345496327187, 'response to virus', 'GO:0009615', ['P0A910']),
#  (0.3323232099521798,
#   'nucleoside triphosphate metabolic process',
#   'GO:0009141',
#   ['P0AB98']),
#  (0.3323232099521798, 'rRNA base methylation', 'GO:0070475', ['P60390']),
#  (0.3323232099521798,
#   'nucleobase catabolic process',
#   'GO:0046113',
#   ['P39831']),
#  (0.3323232099521798, 'potassium ion transport', 'GO:0006813', ['P77338']),
#  (0.34486896402438005,
#   'peptide transport',
#   'GO:0015833',
#   ['P0ADE4', 'P05825', 'P75780']),
#  (0.3464127674114566,
#   'pyrimidine-containing compound catabolic process',
#   'GO:0072529',
#   ['P39831']),
#  (0.36484953868362036,
#   'response to chemical',
#   'GO:0042221',
#   ['P0ADB7',
#    'P0A937',
#    'P02930',
#    'P02931',
#    'P0AER8',
#    'P06129',
#    'P02930',
#    'P76344',
#    'P77330',
#    'P0AB40',
#    'P02930']),
#  (0.36801687412151907,
#   'regulation of cellular protein metabolic process',
#   'GO:0032268',
#   ['P0ACF8', 'P68919']),
#  (0.36801687412151907,
#   'anion transmembrane transport',
#   'GO:0098656',
#   ['P23173', 'P0AER8']),
#  (0.37371895138059447,
#   'regulation of DNA-templated transcription, initiation',
#   'GO:2000142',
#   ['P0AFJ5']),
#  (0.37371895138059447, 'cell redox homeostasis', 'GO:0045454', ['P0AC69']),
#  (0.37371895138059447,
#   'proton transmembrane transport',
#   'GO:1902600',
#   ['P0AB98']),
#  (0.37371895138059447,
#   'response to external biotic stimulus',
#   'GO:0043207',
#   ['P0A910']),
#  (0.37371895138059447, 'response to other organism', 'GO:0051707', ['P0A910']),
#  (0.38694746028901233, 'rRNA methylation', 'GO:0031167', ['P60390']),
#  (0.38694746028901233,
#   'cellular iron ion homeostasis',
#   'GO:0006879',
#   ['P05825', 'P05825']),
#  (0.3999006359940379,
#   'negative regulation of translation',
#   'GO:0017148',
#   ['P68919']),
#  (0.3999006359940379,
#   'negative regulation of cellular amide metabolic process',
#   'GO:0034249',
#   ['P68919']),
#  (0.3999006359940379,
#   'fatty acid biosynthetic process',
#   'GO:0006633',
#   ['P0AEK2', 'P0AEK2']),
#  (0.3999006359940379, 'lipid catabolic process', 'GO:0016042', ['P0A921']),
#  (0.4125841241291795,
#   'glutamine family amino acid biosynthetic process',
#   'GO:0009084',
#   ['P0A9L8']),
#  (0.413099825342554,
#   'regulation of protein metabolic process',
#   'GO:0051246',
#   ['P0ACF8', 'P68919']),
#  (0.4250034563107339,
#   'single-species submerged biofilm formation',
#   'GO:0090609',
#   ['P0ACF8']),
#  (0.437164052405172,
#   'negative regulation of cellular protein metabolic process',
#   'GO:0032269',
#   ['P68919']),
#  (0.44907122275214173, 'protein secretion', 'GO:0009306', ['P0ADE4']),
#  (0.44907122275214173, 'secretion', 'GO:0046903', ['P0ADE4']),
#  (0.44907122275214173, 'peptide secretion', 'GO:0002790', ['P0ADE4']),
#  (0.44907122275214173, 'secretion by cell', 'GO:0032940', ['P0ADE4']),
#  (0.44907122275214173,
#   'establishment of protein localization to extracellular region',
#   'GO:0035592',
#   ['P0ADE4']),
#  (0.4607301703439318,
#   'monosaccharide transmembrane transport',
#   'GO:0015749',
#   ['P0AGI1']),
#  (0.46367789226745026,
#   'protein complex oligomerization',
#   'GO:0051259',
#   ['P0AB52', 'P02931']),
#  (0.4721459929622434,
#   'pyrimidine nucleobase metabolic process',
#   'GO:0006206',
#   ['P39831']),
#  (0.4721459929622434, 'rRNA modification', 'GO:0000154', ['P60390']),
#  (0.4721459929622434,
#   'negative regulation of protein metabolic process',
#   'GO:0051248',
#   ['P68919']),
#  (0.4721459929622434,
#   'cellular response to starvation',
#   'GO:0009267',
#   ['P76344']),
#  (0.4721459929622434,
#   'cellular transition metal ion homeostasis',
#   'GO:0046916',
#   ['P05825', 'P05825']),
#  (0.48332368527309333,
#   'DNA-templated transcription, initiation',
#   'GO:0006352',
#   ['P0AFJ5']),
#  (0.48332368527309333,
#   'cellular biogenic amine catabolic process',
#   'GO:0042402',
#   ['P23173']),
#  (0.48332368527309333,
#   'establishment of localization in cell',
#   'GO:0051649',
#   ['P05825', 'P05825']),
#  (0.48332368527309333,
#   'cellular metal ion homeostasis',
#   'GO:0006875',
#   ['P05825', 'P05825']),
#  (0.4914488815605624,
#   'multi-organism cellular process',
#   'GO:0044764',
#   ['P0ACF8', 'P0A910']),
#  (0.4942681408806507, 'amine catabolic process', 'GO:0009310', ['P23173']),
#  (0.5049841543408011,
#   'cellular response to nutrient levels',
#   'GO:0031669',
#   ['P76344']),
#  (0.5082947385332551,
#   'multi-organism process',
#   'GO:0051704',
#   ['P0ACF8', 'P0A910', 'P0A927', 'P0A910', 'P0A910']),
#  (0.5183262301403793,
#   'response to temperature stimulus',
#   'GO:0009266',
#   ['P23894', 'P0A7G2']),
#  (0.5257495496067226, 'export from cell', 'GO:0140352', ['P0ADE4']),
#  (0.5358080428565956,
#   'aromatic amino acid family metabolic process',
#   'GO:0009072',
#   ['P23173']),
#  (0.5358080428565956, 'RNA methylation', 'GO:0001510', ['P60390']),
#  (0.5456563206047299, 'response to starvation', 'GO:0042594', ['P76344']),
#  (0.5489553545870016,
#   'gene expression',
#   'GO:0010467',
#   ['P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P60390',
#    'P0A7G2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399']),
#  (0.5546264680746639,
#   'organonitrogen compound metabolic process',
#   'GO:1901564',
#   ['P39831',
#    'P23173',
#    'P60955',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P23894',
#    'P09169',
#    'P0AEK2',
#    'P0AB98',
#    'P0A9L8',
#    'P0A908']),
#  (0.5568825895659119,
#   'amino acid transport',
#   'GO:0006865',
#   ['P23173', 'P0AER8']),
#  (0.5647394544739288,
#   'cellular cation homeostasis',
#   'GO:0030003',
#   ['P05825', 'P05825']),
#  (0.5739827053614878,
#   'carbohydrate transmembrane transport',
#   'GO:0034219',
#   ['P0AGI1']),
#  (0.5739827053614878,
#   'cellular ion homeostasis',
#   'GO:0006873',
#   ['P05825', 'P05825']),
#  (0.5753453502095529,
#   'heterocycle catabolic process',
#   'GO:0046700',
#   ['P39831', 'P23173']),
#  (0.5830325337510818, 'response to nutrient levels', 'GO:0031667', ['P76344']),
#  (0.6005677919139694,
#   'monocarboxylic acid biosynthetic process',
#   'GO:0072330',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2']),
#  (0.6005677919139694, 'macromolecule methylation', 'GO:0043414', ['P60390']),
#  (0.6106108131126413, 'ncRNA processing', 'GO:0034470', ['P60390', 'P0A7G2']),
#  (0.6173761667618595,
#   'peptidoglycan biosynthetic process',
#   'GO:0009252',
#   ['P0A908']),
#  (0.6173761667618595,
#   'alpha-amino acid catabolic process',
#   'GO:1901606',
#   ['P23173']),
#  (0.6173761667618595,
#   'glycosaminoglycan biosynthetic process',
#   'GO:0006024',
#   ['P0A908']),
#  (0.6173761667618595,
#   'aminoglycan biosynthetic process',
#   'GO:0006023',
#   ['P0A908']),
#  (0.6218719118449587,
#   'cellular nitrogen compound catabolic process',
#   'GO:0044270',
#   ['P39831', 'P23173']),
#  (0.622004474275708,
#   'drug metabolic process',
#   'GO:0017144',
#   ['P39831', 'P0AEK2', 'P0AB98', 'P0A9L8']),
#  (0.6255170993839474,
#   'cell wall macromolecule biosynthetic process',
#   'GO:0044038',
#   ['P0A908']),
#  (0.6255170993839474,
#   'cellular component macromolecule biosynthetic process',
#   'GO:0070589',
#   ['P0A908']),
#  (0.6334873517159918,
#   'purine ribonucleotide biosynthetic process',
#   'GO:0009152',
#   ['P0AB98']),
#  (0.6334873517159918,
#   'cellular biogenic amine metabolic process',
#   'GO:0006576',
#   ['P23173']),
#  (0.6334873517159918,
#   'inorganic cation transmembrane transport',
#   'GO:0098662',
#   ['P0AB98']),
#  (0.6412904490896902,
#   'nucleobase metabolic process',
#   'GO:0009112',
#   ['P39831']),
#  (0.6489298451198844, 'amine metabolic process', 'GO:0009308', ['P23173']),
#  (0.6489298451198844,
#   'cellular amine metabolic process',
#   'GO:0044106',
#   ['P23173']),
#  (0.6489298451198844, 'cell wall biogenesis', 'GO:0042546', ['P0A908']),
#  (0.6489298451198844, 'cell adhesion', 'GO:0007155', ['P0A940']),
#  (0.6554235671015238,
#   'cellular response to DNA damage stimulus',
#   'GO:0006974',
#   ['P02943', 'P0A7G2', 'P0A910', 'P06996', 'P0A9H1']),
#  (0.6564089231411779,
#   'purine nucleotide biosynthetic process',
#   'GO:0006164',
#   ['P0AB98']),
#  (0.6744960329243482, 'RNA processing', 'GO:0006396', ['P60390', 'P0A7G2']),
#  (0.6847873401116049,
#   'cell wall macromolecule metabolic process',
#   'GO:0044036',
#   ['P0A908']),
#  (0.6891045849687076,
#   'carboxylic acid transport',
#   'GO:0046942',
#   ['P23173', 'P0AER8']),
#  (0.6915132153385226,
#   'glutamine family amino acid metabolic process',
#   'GO:0009064',
#   ['P0A9L8']),
#  (0.6915132153385226,
#   'single-species biofilm formation',
#   'GO:0044010',
#   ['P0ACF8']),
#  (0.6938555838128901,
#   'organic acid transport',
#   'GO:0015849',
#   ['P23173', 'P0AER8']),
#  (0.6938555838128901,
#   'carbohydrate transport',
#   'GO:0008643',
#   ['P0AGI1', 'P02943']),
#  (0.6980976736285255,
#   'purine-containing compound biosynthetic process',
#   'GO:0072522',
#   ['P0AB98']),
#  (0.6980976736285255,
#   'cellular amino acid catabolic process',
#   'GO:0009063',
#   ['P23173']),
#  (0.6980976736285255,
#   'fatty acid metabolic process',
#   'GO:0006631',
#   ['P0AEK2', 'P0AEK2']),
#  (0.6985478424840943,
#   'sulfur compound metabolic process',
#   'GO:0006790',
#   ['P0AG78', 'P0AEK2']),
#  (0.7053818302826815,
#   'cellular macromolecule biosynthetic process',
#   'GO:0034645',
#   ['P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908']),
#  (0.7160645857918956,
#   'macromolecule biosynthetic process',
#   'GO:0009059',
#   ['P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908']),
#  (0.7230790338937663,
#   'ribonucleotide biosynthetic process',
#   'GO:0009260',
#   ['P0AB98']),
#  (0.7230790338937663, 'biofilm formation', 'GO:0042710', ['P0ACF8']),
#  (0.7254871866227028,
#   'organic cyclic compound catabolic process',
#   'GO:1901361',
#   ['P39831', 'P23173']),
#  (0.7289991694167777,
#   'water-soluble vitamin biosynthetic process',
#   'GO:0042364',
#   ['P0AEK2']),
#  (0.7289991694167777,
#   'vitamin biosynthetic process',
#   'GO:0009110',
#   ['P0AEK2']),
#  (0.7293817040895465,
#   'cellular response to stress',
#   'GO:0033554',
#   ['P02943', 'P0A7G2', 'P0A910', 'P06996', 'P0A9H1', 'P76344']),
#  (0.7381931417168659,
#   'negative regulation of cellular macromolecule biosynthetic process',
#   'GO:2000113',
#   ['P68919', 'P0ACF8']),
#  (0.7381931417168659,
#   'negative regulation of macromolecule biosynthetic process',
#   'GO:0010558',
#   ['P68919', 'P0ACF8']),
#  (0.7381931417168659,
#   'response to antibiotic',
#   'GO:0046677',
#   ['P0A937', 'P02930']),
#  (0.7404678867329358,
#   'pyrimidine-containing compound metabolic process',
#   'GO:0072527',
#   ['P39831']),
#  (0.7404678867329358,
#   'ribose phosphate biosynthetic process',
#   'GO:0046390',
#   ['P0AB98']),
#  (0.7423179810174697,
#   'negative regulation of cellular biosynthetic process',
#   'GO:0031327',
#   ['P68919', 'P0ACF8']),
#  (0.7423179810174697,
#   'negative regulation of biosynthetic process',
#   'GO:0009890',
#   ['P68919', 'P0ACF8']),
#  (0.7423179810174697,
#   'response to external stimulus',
#   'GO:0009605',
#   ['P0A910', 'P76344']),
#  (0.7504044796345939,
#   'ncRNA metabolic process',
#   'GO:0034660',
#   ['P60390', 'P0A7G2']),
#  (0.7514581906342105,
#   'sulfur compound biosynthetic process',
#   'GO:0044272',
#   ['P0AEK2']),
#  (0.7514581906342105, 'response to toxic substance', 'GO:0009636', ['P0ADB7']),
#  (0.7567801149638708, 'drug catabolic process', 'GO:0042737', ['P39831']),
#  (0.758276311864134,
#   'negative regulation of nitrogen compound metabolic process',
#   'GO:0051172',
#   ['P68919', 'P0ACF8']),
#  (0.7670894240604161,
#   'cellular response to extracellular stimulus',
#   'GO:0031668',
#   ['P76344']),
#  (0.7696893840253967,
#   'negative regulation of cellular metabolic process',
#   'GO:0031324',
#   ['P68919', 'P0ACF8']),
#  (0.7697701941321037,
#   'cellular nitrogen compound biosynthetic process',
#   'GO:0044271',
#   ['P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0AB98',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.7770403200047469,
#   'negative regulation of gene expression',
#   'GO:0010629',
#   ['P68919', 'P0ACF8']),
#  (0.781751340193477,
#   'glycosaminoglycan metabolic process',
#   'GO:0030203',
#   ['P0A908']),
#  (0.781751340193477, 'vitamin metabolic process', 'GO:0006766', ['P0AEK2']),
#  (0.781751340193477,
#   'water-soluble vitamin metabolic process',
#   'GO:0006767',
#   ['P0AEK2']),
#  (0.7864335880983879,
#   'purine ribonucleotide metabolic process',
#   'GO:0009150',
#   ['P0AB98']),
#  (0.7910168519028108,
#   'aminoglycan metabolic process',
#   'GO:0006022',
#   ['P0A908']),
#  (0.7910168519028108,
#   'cation transmembrane transport',
#   'GO:0098655',
#   ['P0AB98']),
#  (0.8041931432107872,
#   'purine nucleotide metabolic process',
#   'GO:0006163',
#   ['P0AB98']),
#  (0.8041931432107872,
#   'response to extracellular stimulus',
#   'GO:0009991',
#   ['P76344']),
#  (0.8204960883969437, 'RNA modification', 'GO:0009451', ['P60390']),
#  (0.8228292778778504,
#   'response to stimulus',
#   'GO:0050896',
#   ['P02943',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P0A9H1',
#    'P76344',
#    'P0A7G2',
#    'P77330',
#    'P23894',
#    'P68919',
#    'P0ADB7',
#    'P0A937',
#    'P02930',
#    'P02931',
#    'P0AER8',
#    'P06129',
#    'P02930',
#    'P76344',
#    'P0AB40',
#    'P02930',
#    'P0A910']),
#  (0.8230586421103672,
#   'negative regulation of macromolecule metabolic process',
#   'GO:0010605',
#   ['P68919', 'P0ACF8']),
#  (0.8243582470602079, 'DNA repair', 'GO:0006281', ['P0A9H1']),
#  (0.8289021183401235,
#   'negative regulation of metabolic process',
#   'GO:0009892',
#   ['P68919', 'P0ACF8']),
#  (0.8390049771373571, 'protein transport', 'GO:0015031', ['P0ADE4']),
#  (0.8458702947884982,
#   'ribonucleotide metabolic process',
#   'GO:0009259',
#   ['P0AB98']),
#  (0.8524470397651427,
#   'cell wall organization or biogenesis',
#   'GO:0071554',
#   ['P0A908']),
#  (0.8531371317239175,
#   'negative regulation of cellular process',
#   'GO:0048523',
#   ['P68919', 'P0ACF8', 'P0ACF8']),
#  (0.8556309522726261,
#   'ribose phosphate metabolic process',
#   'GO:0019693',
#   ['P0AB98']),
#  (0.8556309522726261,
#   'cellular response to chemical stimulus',
#   'GO:0070887',
#   ['P77330']),
#  (0.867703646161856,
#   'nucleotide biosynthetic process',
#   'GO:0009165',
#   ['P0AB98']),
#  (0.867703646161856,
#   'nucleoside phosphate biosynthetic process',
#   'GO:1901293',
#   ['P0AB98']),
#  (0.867703646161856,
#   'negative regulation of transcription, DNA-templated',
#   'GO:0045892',
#   ['P0ACF8']),
#  (0.867703646161856,
#   'negative regulation of nucleic acid-templated transcription',
#   'GO:1903507',
#   ['P0ACF8']),
#  (0.867703646161856,
#   'negative regulation of RNA biosynthetic process',
#   'GO:1902679',
#   ['P0ACF8']),
#  (0.867703646161856,
#   'purine-containing compound metabolic process',
#   'GO:0072521',
#   ['P0AB98']),
#  (0.8705629544544868, 'response to radiation', 'GO:0009314', ['P68919']),
#  (0.8759508883238359,
#   'cellular response to stimulus',
#   'GO:0051716',
#   ['P02943', 'P0A7G2', 'P0A910', 'P06996', 'P0A9H1', 'P76344', 'P77330']),
#  (0.8762741677194931,
#   'response to abiotic stimulus',
#   'GO:0009628',
#   ['P23894', 'P0A7G2', 'P68919']),
#  (0.8787805921319898,
#   'negative regulation of RNA metabolic process',
#   'GO:0051253',
#   ['P0ACF8']),
#  (0.8839712276910839,
#   'negative regulation of nucleobase-containing compound metabolic process',
#   'GO:0045934',
#   ['P0ACF8']),
#  (0.8887414426614033,
#   'organonitrogen compound catabolic process',
#   'GO:1901565',
#   ['P39831', 'P23173']),
#  (0.8937043510224091,
#   'aromatic compound catabolic process',
#   'GO:0019439',
#   ['P23173']),
#  (0.905130426579081,
#   'negative regulation of biological process',
#   'GO:0048519',
#   ['P68919', 'P0ACF8', 'P0ACF8']),
#  (0.9068148491219121,
#   'coenzyme biosynthetic process',
#   'GO:0009108',
#   ['P0AEK2']),
#  (0.9116780640133624,
#   'lipid metabolic process',
#   'GO:0006629',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A921']),
#  (0.9146562547305982,
#   'cellular protein modification process',
#   'GO:0006464',
#   ['P0A6K3', 'P0A6K3']),
#  (0.9146562547305982,
#   'alpha-amino acid biosynthetic process',
#   'GO:1901607',
#   ['P0A9L8']),
#  (0.9146562547305982,
#   'protein modification process',
#   'GO:0036211',
#   ['P0A6K3', 'P0A6K3']),
#  (0.9147935951413512,
#   'alpha-amino acid metabolic process',
#   'GO:1901605',
#   ['P23173', 'P0A9L8']),
#  (0.9211286359215682,
#   'biological regulation',
#   'GO:0065007',
#   ['P77338',
#    'P05825',
#    'P05825',
#    'P0AC69',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0ACF8']),
#  (0.9221444373071859,
#   'carboxylic acid biosynthetic process',
#   'GO:0046394',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A9L8']),
#  (0.9221444373071859,
#   'organic acid biosynthetic process',
#   'GO:0016053',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A9L8']),
#  (0.9255264523768024,
#   'regulation of cellular macromolecule biosynthetic process',
#   'GO:2000112',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9266274351935263,
#   'regulation of macromolecule biosynthetic process',
#   'GO:0010556',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9298450147130781,
#   'regulation of cellular biosynthetic process',
#   'GO:0031326',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9319203983152453,
#   'regulation of biosynthetic process',
#   'GO:0009889',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.937459847834448,
#   'regulation of RNA biosynthetic process',
#   'GO:2001141',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.937459847834448,
#   'regulation of nucleic acid-templated transcription',
#   'GO:1903506',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.937459847834448,
#   'regulation of transcription, DNA-templated',
#   'GO:0006355',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.9385984533361976,
#   'macromolecule modification',
#   'GO:0043412',
#   ['P60390', 'P0A6K3', 'P0A6K3']),
#  (0.9400252015573146, 'coenzyme metabolic process', 'GO:0006732', ['P0AEK2']),
#  (0.9400252015573146,
#   'cellular amino acid biosynthetic process',
#   'GO:0008652',
#   ['P0A9L8']),
#  (0.9423935483934902,
#   'regulation of gene expression',
#   'GO:0010468',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9463058479311096,
#   'nucleotide metabolic process',
#   'GO:0009117',
#   ['P0AB98']),
#  (0.9474818885288918,
#   'nucleoside phosphate metabolic process',
#   'GO:0006753',
#   ['P0AB98']),
#  (0.9478954938878332,
#   'regulation of RNA metabolic process',
#   'GO:0051252',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.9480245725595521,
#   'nucleobase-containing small molecule metabolic process',
#   'GO:0055086',
#   ['P39831', 'P0AB98']),
#  (0.9498687709539531,
#   'regulation of nitrogen compound metabolic process',
#   'GO:0051171',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.951937569857779,
#   'lipid biosynthetic process',
#   'GO:0008610',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2']),
#  (0.955225101301368,
#   'regulation of nucleobase-containing compound metabolic process',
#   'GO:0019219',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.9564624625255473,
#   'regulation of primary metabolic process',
#   'GO:0080090',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.957144611573385,
#   'regulation of cellular metabolic process',
#   'GO:0031323',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9609258999291524,
#   'macromolecule metabolic process',
#   'GO:0043170',
#   ['P0A9H1',
#    'P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908',
#    'P60390',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P0A7G2',
#    'P23894',
#    'P09169']),
#  (0.963957974627908,
#   'cellular macromolecule metabolic process',
#   'GO:0044260',
#   ['P0A9H1',
#    'P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908',
#    'P60390',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3']),
#  (0.9651749117420553,
#   'regulation of macromolecule metabolic process',
#   'GO:0060255',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9677961926004862,
#   'carboxylic acid catabolic process',
#   'GO:0046395',
#   ['P23173']),
#  (0.9705490955761887,
#   'cellular amino acid metabolic process',
#   'GO:0006520',
#   ['P23173', 'P0A9L8']),
#  (0.9705490955761887,
#   'carbohydrate derivative biosynthetic process',
#   'GO:1901137',
#   ['P0AB98', 'P0A908']),
#  (0.9725578466973962,
#   'response to stress',
#   'GO:0006950',
#   ['P02943', 'P0A7G2', 'P0A910', 'P06996', 'P0A9H1', 'P76344', 'P0A7G2']),
#  (0.9730670375292659,
#   'organic acid catabolic process',
#   'GO:0016054',
#   ['P23173']),
#  (0.9733958166966922,
#   'cellular nitrogen compound metabolic process',
#   'GO:0034641',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919']),
#  (0.9736094192254855,
#   'regulation of metabolic process',
#   'GO:0019222',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919']),
#  (0.9736629782444374,
#   'cofactor biosynthetic process',
#   'GO:0051188',
#   ['P0AEK2']),
#  (0.9747319413034665,
#   'nucleic acid-templated transcription',
#   'GO:0097659',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.9747319413034665,
#   'transcription, DNA-templated',
#   'GO:0006351',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.9788548478981596,
#   'RNA biosynthetic process',
#   'GO:0032774',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8']),
#  (0.97941931526859,
#   'cellular lipid metabolic process',
#   'GO:0044255',
#   ['P0AEK2', 'P0AEK2']),
#  (0.9816073524701424,
#   'organophosphate biosynthetic process',
#   'GO:0090407',
#   ['P0AB98']),
#  (0.9835942625823828,
#   'organic substance biosynthetic process',
#   'GO:1901576',
#   ['P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908',
#    'P0AEK2',
#    'P0AB98',
#    'P0A9L8',
#    'P0AEK2',
#    'P0AEK2',
#    'P0AEK2']),
#  (0.9838092449881909,
#   'cellular biosynthetic process',
#   'GO:0044249',
#   ['P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908',
#    'P0AB98',
#    'P0AEK2',
#    'P0A9L8',
#    'P0AEK2',
#    'P0AEK2']),
#  (0.985673180247369,
#   'RNA metabolic process',
#   'GO:0016070',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P60390', 'P0A7G2']),
#  (0.9859669638925985, 'cofactor metabolic process', 'GO:0051186', ['P0AEK2']),
#  (0.9874669717519146,
#   'monocarboxylic acid metabolic process',
#   'GO:0032787',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2']),
#  (0.9888412838299091,
#   'regulation of cellular process',
#   'GO:0050794',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919', 'P0AC69', 'P0ACF8']),
#  (0.989060127425917,
#   'biosynthetic process',
#   'GO:0009058',
#   ['P60955',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P0ACF8',
#    'P68919',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0A908',
#    'P0AEK2',
#    'P0AB98',
#    'P0A9L8',
#    'P0AEK2',
#    'P0AEK2',
#    'P0AEK2']),
#  (0.9900547302320559,
#   'small molecule biosynthetic process',
#   'GO:0044283',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A9L8']),
#  (0.9917348586880163,
#   'heterocycle biosynthetic process',
#   'GO:0018130',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0AB98', 'P0AEK2', 'P0A9L8']),
#  (0.9922425092177531,
#   'nitrogen compound metabolic process',
#   'GO:0006807',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P60955',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P23894',
#    'P09169',
#    'P0A9L8',
#    'P0A908']),
#  (0.9934616171380878,
#   'organic cyclic compound biosynthetic process',
#   'GO:1901362',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0AB98', 'P0AEK2', 'P0A9L8']),
#  (0.9942191643370436, 'DNA metabolic process', 'GO:0006259', ['P0A9H1']),
#  (0.9943145007218321,
#   'nucleobase-containing compound biosynthetic process',
#   'GO:0034654',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0AB98']),
#  (0.9943977651484787,
#   'regulation of biological process',
#   'GO:0050789',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0ACF8', 'P68919', 'P0AC69', 'P0ACF8']),
#  (0.9962197790361661,
#   'cellular catabolic process',
#   'GO:0044248',
#   ['P39831', 'P23173']),
#  (0.9965130178503011,
#   'small molecule catabolic process',
#   'GO:0044282',
#   ['P23173']),
#  (0.996670269567472,
#   'organophosphate metabolic process',
#   'GO:0019637',
#   ['P0AB98']),
#  (0.9974309952775733,
#   'organic substance catabolic process',
#   'GO:1901575',
#   ['P39831', 'P23173', 'P0A921']),
#  (0.9976235400324758,
#   'carbohydrate derivative metabolic process',
#   'GO:1901135',
#   ['P0AB98', 'P0A908']),
#  (0.9979811478248417,
#   'catabolic process',
#   'GO:0009056',
#   ['P39831', 'P23173', 'P0A921']),
#  (0.9983514580934333,
#   'carboxylic acid metabolic process',
#   'GO:0019752',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A9L8', 'P23173']),
#  (0.9987736743751655,
#   'nucleic acid metabolic process',
#   'GO:0090304',
#   ['P0A9H1', 'P0ACG1', 'P0AFJ5', 'P0ACF8', 'P60390', 'P0A7G2']),
#  (0.9989857333394949,
#   'aromatic compound biosynthetic process',
#   'GO:0019438',
#   ['P0ACG1', 'P0AFJ5', 'P0ACF8', 'P0AB98']),
#  (0.9991125103022583,
#   'heterocycle metabolic process',
#   'GO:0046483',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A9L8']),
#  (0.9991975045312967,
#   'phosphate-containing compound metabolic process',
#   'GO:0006796',
#   ['P0AB98']),
#  (0.9991990975627043,
#   'organic acid metabolic process',
#   'GO:0006082',
#   ['P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A9L8', 'P23173']),
#  (0.9994843123769013,
#   'primary metabolic process',
#   'GO:0044238',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P60955',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P23894',
#    'P09169',
#    'P0AEK2',
#    'P0AEK2',
#    'P0AEK2',
#    'P0A921',
#    'P23173',
#    'P0A9L8']),
#  (0.9995453634146458,
#   'phosphorus metabolic process',
#   'GO:0006793',
#   ['P0AB98']),
#  (0.9995942869037334,
#   'organic cyclic compound metabolic process',
#   'GO:1901360',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A9L8']),
#  (0.9997256980048433,
#   'nucleobase-containing compound metabolic process',
#   'GO:0006139',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2']),
#  (0.9999272536855237,
#   'cellular aromatic compound metabolic process',
#   'GO:0006725',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173']),
#  (0.9999728343897353,
#   'cellular process',
#   'GO:0009987',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A9L8',
#    'P0AG78',
#    'P60955',
#    'P0A908',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P0AEK2',
#    'P0AEK2',
#    'P02943',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P77330',
#    'P0AB52',
#    'P02931',
#    'P0A7M6',
#    'P68919',
#    'P62399',
#    'P0A7T3',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P77338',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P05825',
#    'P05825',
#    'P0AC69',
#    'P0ACF8',
#    'P0ADE4',
#    'P0A910']),
#  (0.9999823251766027,
#   'small molecule metabolic process',
#   'GO:0044281',
#   ['P39831', 'P0AB98', 'P0AEK2', 'P0AEK2', 'P0AEK2', 'P0A9L8', 'P23173']),
#  (0.999998554586707,
#   'organic substance metabolic process',
#   'GO:0071704',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A9L8',
#    'P60955',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P23894',
#    'P09169',
#    'P0A908',
#    'P0A921',
#    'P0AEK2',
#    'P0AEK2',
#    'P0AEK2']),
#  (0.9999995026364981,
#   'cellular metabolic process',
#   'GO:0044237',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A9L8',
#    'P0AG78',
#    'P60955',
#    'P0A908',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P0AEK2',
#    'P0AEK2']),
#  (0.9999999108250931,
#   'metabolic process',
#   'GO:0008152',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A9L8',
#    'P0AG78',
#    'P60955',
#    'P0A908',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P0AEK2',
#    'P0AEK2',
#    'P23894',
#    'P09169',
#    'P0AEK2',
#    'P0A921']),
#  (1.0,
#   'biological_process',
#   'GO:0008150',
#   ['P39831',
#    'P0AB98',
#    'P0A9H1',
#    'P0ACG1',
#    'P0AFJ5',
#    'P0ACF8',
#    'P60390',
#    'P0A7G2',
#    'P23173',
#    'P0AEK2',
#    'P0A7M6',
#    'P0A7M9',
#    'P0A7T3',
#    'P02358',
#    'P68919',
#    'P0A6K3',
#    'P0A7K2',
#    'P62399',
#    'P0ACF8',
#    'P68919',
#    'P0A9L8',
#    'P0AG78',
#    'P60955',
#    'P0A908',
#    'P0A7A5',
#    'P0A6K3',
#    'P0A6K3',
#    'P0AEK2',
#    'P0AEK2',
#    'P23894',
#    'P09169',
#    'P0AEK2',
#    'P0A921',
#    'P02943',
#    'P0A7G2',
#    'P0A910',
#    'P06996',
#    'P76344',
#    'P77330',
#    'P0AB52',
#    'P02931',
#    'P0A7M6',
#    'P68919',
#    'P62399',
#    'P0A7T3',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P77338',
#    'P0A903',
#    'P77774',
#    'P0A940',
#    'P0A937',
#    'P76506',
#    'P05825',
#    'P05825',
#    'P0AC69',
#    'P0ACF8',
#    'P0ADE4',
#    'P0A910',
#    'P02943',
#    'P0A927',
#    'P0A910',
#    'P0AG78',
#    'P0AFJ5',
#    'P23173',
#    'P0AER8',
#    'P02930',
#    'P06996',
#    'P77338',
#    'P13036',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A910',
#    'P06129',
#    'P02930',
#    'P02931',
#    'P77338',
#    'P0AGI1',
#    'P02931',
#    'P02943',
#    'P05825',
#    'P75780',
#    'P0A927',
#    'P06129',
#    'P02930',
#    'P0A7G2',
#    'P23894',
#    'P68919',
#    'P0ADB7',
#    'P0A937',
#    'P02930',
#    'P76344',
#    'P0AB40',
#    'P02930',
#    'P0A910',
#    'P0AB28',
#    'P13036',
#    'P06971',
#    'P75780',
#    'P0A940',
#    'P0A927',
#    'P0A910'])]

# %%
mf = o.molecular_function(l_go)
# Out:
# molecular function process GO Tree
# Extracting molecular function ontology
# Applying true path collapsing
# 181 GO terms, 143 leaves, 49 proteins
# Extracting molecular function ontology
# Applying true path collapsing
# 2264 GO terms, 7807 leaves, 3118 proteins
# Evaluated 180 / 180 Pathways, based on 67 proteins

# %%
cc = o.cellular_component(l_go)
# Out:
# cellular component process GO Tree
# Extracting cellular component ontology
# Applying true path collapsing
# 61 GO terms, 128 leaves, 65 proteins
# Extracting cellular component ontology
# Applying true path collapsing
# 239 GO terms, 4698 leaves, 2805 proteins
# Evaluated 60 / 60 Pathways, based on 67 proteins

# %% [markdown]
# ## Une première application: représentation riche du résultat de l'analyse
#
#
# ### Mise en forme "riche" des résultats grâce au notebook
#
# Jupyter permet d'étendre le concept de la méthode **__str__()** afin de produire du contenu HTML.
#  Ainsi, tout objet impémentant une méthode **_repr_html_()** sera affiché, via son rendu HTML, dans la cellule d'un notebook.
#
# ```python
# class Point():
#     def __init__(self, x, y, z):
#         self.x = x
#         self.y = y
#         self.z = z
#     def _repr_html_(self):
#         htmlString = "<table><thead><tr><td>Abscisse</td><td>Ordonnée</td><td>Cote</td></tr></thead>"
#         htmlString += f"<tbody><tr><td>{self.x}</td><td>{self.y}</td><td>{self.z}</td></tr></tbody></table>"
#         return htmlString
# Point(2,3,4)
# ```
# Affichera
#
# ![caption](../figs/reprhtml.png)
#
#
# ### Intégration des résultats à la visualisation du notebook
#
# En vous inspirant de la fonction ci-dessus, implémenter une classe Rich_GO_ORA dont la méthode [`_repr_html_`](https://ipython.readthedocs.io/en/stable/config/integrating.html) permettra un affichage plus lisible d'une des analyses `biological_process / molecular_function /cellular_component`
#
# Un exemple possible est,
# ![caption](../figs/_repr_html_.png)
#
# (Bonus): clicker sur le nom du terme GO envoie vers sa description.
# Pour cela, afficher le nom du pathway dans une balise hyperlien pour permettre d'acceder à la page de description du terme GO.
#
# Les termes GO sont accessibles aux URL de la forme
# `http://amigo.geneontology.org/amigo/term/GO:GO_NUMBER`.

# %%
class Rich_GO_ORA():
    def __init__(self, lprot):
        self.lprot = lprot

    def _repr_html_(self):
        htmlString = "<table><thead><tr><td>p-value</td><td>Pathway name</td><td>n</td></tr></thead>"
        for prot in self.lprot:
            htmlString += f"<tbody><tr><td>{prot[0]}</td><td><a href=\"http://amigo.geneontology.org/amigo/term/{prot[2]}\" target=\"_blank\">{prot[1]}</a></td><td>{len(prot[3])}</td></tr></tbody>"
        htmlString += "</table>"
        return htmlString

# %%
Rich_GO_ORA(bp)
# Out:
# <table><thead><tr><td>p-value</td><td>Pathway name</td><td>n</td></tr></thead><tbody><tr><td>2.4384924031076443e-05</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015891" target="_blank">siderophore transport</a></td><td>5</td></tr></tbody><tbody><tr><td>5.561766370326049e-05</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0006811" target="_blank">ion transport</a></td><td>22</td></tr></tbody><tbody><tr><td>0.0001096983582129087</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:1901678" target="_blank">iron coordination entity transport</a></td><td>6</td></tr></tbody><tbody><tr><td>0.0001517600944958151</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0051205" target="_blank">protein insertion into membrane</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0002376596372987538</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0061024" target="_blank">membrane organization</a></td><td>9</td></tr></tbody><tbody><tr><td>0.00026730749824558384</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0043165" target="_blank">Gram-negative-bacterium-type cell outer membrane assembly</a></td><td>4</td></tr></tbody><tbody><tr><td>0.00026730749824558384</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0071709" target="_blank">membrane assembly</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0003440562569104042</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0090150" target="_blank">establishment of protein localization to membrane</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0009106481040647094</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0006826" target="_blank">iron ion transport</a></td><td>7</td></tr></tbody><tbody><tr><td>0.001029678690889067</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0051234" target="_blank">establishment of localization</a></td><td>36</td></tr></tbody><tbody><tr><td>0.0030544720005266073</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0006412" target="_blank">translation</a></td><td>10</td></tr></tbody><tbody><tr><td>0.003524298545195742</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0051179" target="_blank">localization</a></td><td>36</td></tr></tbody><tbody><tr><td>0.0035775184651053848</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022613" target="_blank">ribonucleoprotein complex biogenesis</a></td><td>7</td></tr></tbody><tbody><tr><td>0.0035775184651053848</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0042254" target="_blank">ribosome biogenesis</a></td><td>7</td></tr></tbody><tbody><tr><td>0.0036458270107751403</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0034613" target="_blank">cellular protein localization</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0036458270107751403</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0070727" target="_blank">cellular macromolecule localization</a></td><td>4</td></tr></tbody><tbody><tr><td>0.003911683388498183</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0051641" target="_blank">cellular localization</a></td><td>6</td></tr></tbody><tbody><tr><td>0.004164563090996108</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015914" target="_blank">phospholipid transport</a></td><td>2</td></tr></tbody><tbody><tr><td>0.004167624043539427</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0033036" target="_blank">macromolecule localization</a></td><td>8</td></tr></tbody><tbody><tr><td>0.005187046033618788</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0043043" target="_blank">peptide biosynthetic process</a></td><td>10</td></tr></tbody><tbody><tr><td>0.00653842955812019</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0043604" target="_blank">amide biosynthetic process</a></td><td>11</td></tr></tbody><tbody><tr><td>0.007258368952379507</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044085" targe ...

# %%
Rich_GO_ORA(mf)
# Out:
# <table><thead><tr><td>p-value</td><td>Pathway name</td><td>n</td></tr></thead><tbody><tr><td>1.1519075123173558e-06</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015288" target="_blank">porin activity</a></td><td>9</td></tr></tbody><tbody><tr><td>2.2463488413599903e-06</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015267" target="_blank">channel activity</a></td><td>14</td></tr></tbody><tbody><tr><td>0.00020347570292695698</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0005198" target="_blank">structural molecule activity</a></td><td>8</td></tr></tbody><tbody><tr><td>0.0002927913218899773</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0003735" target="_blank">structural constituent of ribosome</a></td><td>7</td></tr></tbody><tbody><tr><td>0.00034817734327228746</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0019904" target="_blank">protein domain specific binding</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0006757861606588795</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0038023" target="_blank">signaling receptor activity</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0012919518075641485</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0047485" target="_blank">protein N-terminus binding</a></td><td>2</td></tr></tbody><tbody><tr><td>0.001327690840731892</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0060089" target="_blank">molecular transducer activity</a></td><td>5</td></tr></tbody><tbody><tr><td>0.0025487567789938847</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0042912" target="_blank">colicin transmembrane transporter activity</a></td><td>2</td></tr></tbody><tbody><tr><td>0.0025487567789938847</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022885" target="_blank">bacteriocin transmembrane transporter activity</a></td><td>2</td></tr></tbody><tbody><tr><td>0.0025487567789938847</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0008097" target="_blank">5S rRNA binding</a></td><td>2</td></tr></tbody><tbody><tr><td>0.0025487567789938847</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0030674" target="_blank">protein binding, bridging</a></td><td>2</td></tr></tbody><tbody><tr><td>0.004107160646402862</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0005216" target="_blank">ion channel activity</a></td><td>3</td></tr></tbody><tbody><tr><td>0.008538986001514887</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0019843" target="_blank">rRNA binding</a></td><td>5</td></tr></tbody><tbody><tr><td>0.008562622102479966</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022834" target="_blank">ligand-gated channel activity</a></td><td>2</td></tr></tbody><tbody><tr><td>0.00883189267759601</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015318" target="_blank">inorganic molecular entity transmembrane transporter activity</a></td><td>11</td></tr></tbody><tbody><tr><td>0.013843045558711232</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015075" target="_blank">ion transmembrane transporter activity</a></td><td>12</td></tr></tbody><tbody><tr><td>0.014005572461073822</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0046983" target="_blank">protein dimerization activity</a></td><td>4</td></tr></tbody><tbody><tr><td>0.014081538653534433</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0005515" target="_blank">protein binding</a></td><td>24</td></tr></tbody><tbody><tr><td>0.014284849503993717</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0043225" target="_blank">ATPase-coupled inorganic anion transmembrane transporter activity</a></td><td>2</td></tr></tbody><tbody><tr><td>0.021042713567839197</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031132" target="_blank">serine 3-dehydrogenase activity</a></td><td>1</td></tr></tbody><tbody><tr><td>0.021042713567839197</ ...

# %%
Rich_GO_ORA(cc)
# Out:
# <table><thead><tr><td>p-value</td><td>Pathway name</td><td>n</td></tr></thead><tbody><tr><td>6.89445722881441e-19</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0009279" target="_blank">cell outer membrane</a></td><td>36</td></tr></tbody><tbody><tr><td>6.89445722881441e-19</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044462" target="_blank">external encapsulating structure part</a></td><td>36</td></tr></tbody><tbody><tr><td>5.230046427974166e-18</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0019867" target="_blank">outer membrane</a></td><td>37</td></tr></tbody><tbody><tr><td>6.2344065122180476e-18</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0030312" target="_blank">external encapsulating structure</a></td><td>36</td></tr></tbody><tbody><tr><td>4.111566662123124e-14</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0030313" target="_blank">cell envelope</a></td><td>40</td></tr></tbody><tbody><tr><td>2.3379804156111627e-10</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031230" target="_blank">intrinsic component of cell outer membrane</a></td><td>12</td></tr></tbody><tbody><tr><td>3.377004071113939e-07</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0045203" target="_blank">integral component of cell outer membrane</a></td><td>6</td></tr></tbody><tbody><tr><td>1.2588446729423602e-05</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0046930" target="_blank">pore complex</a></td><td>6</td></tr></tbody><tbody><tr><td>1.7765656248603392e-05</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:1990063" target="_blank">Bam protein complex</a></td><td>4</td></tr></tbody><tbody><tr><td>7.599336936164626e-05</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0098796" target="_blank">membrane protein complex</a></td><td>15</td></tr></tbody><tbody><tr><td>0.00016609054412549036</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031246" target="_blank">intrinsic component of periplasmic side of cell outer membrane</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0003147340562808892</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0032991" target="_blank">protein-containing complex</a></td><td>25</td></tr></tbody><tbody><tr><td>0.00040094878803341764</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0031241" target="_blank">periplasmic side of cell outer membrane</a></td><td>4</td></tr></tbody><tbody><tr><td>0.0004944739981444133</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022626" target="_blank">cytosolic ribosome</a></td><td>7</td></tr></tbody><tbody><tr><td>0.0004944739981444133</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044391" target="_blank">ribosomal subunit</a></td><td>8</td></tr></tbody><tbody><tr><td>0.0007970797255525597</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0005840" target="_blank">ribosome</a></td><td>8</td></tr></tbody><tbody><tr><td>0.0008722531456023229</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:1990904" target="_blank">ribonucleoprotein complex</a></td><td>8</td></tr></tbody><tbody><tr><td>0.0012895366432122673</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0022625" target="_blank">cytosolic large ribosomal subunit</a></td><td>5</td></tr></tbody><tbody><tr><td>0.0012895366432122673</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0015934" target="_blank">large ribosomal subunit</a></td><td>6</td></tr></tbody><tbody><tr><td>0.0015688918031231559</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044446" target="_blank">intracellular organelle part</a></td><td>8</td></tr></tbody><tbody><tr><td>0.002459883837502732</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0044445" target="_blank">cytosolic part</a></td><td>7</td></tr></tbody><tbody><tr><td>0.007552940633117851</td><td><a href="http://amigo.geneontology.org/amigo/term/GO:0043232" targ ...

# %% [markdown]
# ## Une deuxième application: volcano plot améliorés
# ###### PANDAS
# En choisissant comme seuil la valeur `alpha` du TP précédent, veuillez extraires les identifiants uniprot des protéines sur-abondantes (rappel les valeurs d'abondance sont celles de la colonne `Log2 Corrected Abundance Ratio`).
#
# Vous devrez avoir dans des listes distinctes:
# * identifiants uniprot
# * `Log2 Corrected Abundance Ratio`
# * `LOG10 Adj.P-val'`
#
# ###### Représentation graphiques
# * Pour la catégorie de termes GO (biological_process / molecular_function /cellular_component) de votre choix
#     * Générer une grille de 4 graphiques
#     * Dans chaque graphique colorez dans une couleur différentes les protéines porteuses de 4 termes de GO que vous estimez les plus pertinents
#     * Donnez le nom de la catégorie générale à la grille
#     * Donnez le nom du terme GO représenté dans chaque graphique avec une couleur de titre cohérente.

# %%
alpha = -0.096
# df.loc["Log2 Corrected Abundance Ratio">=alpha]["Accession"].to_list()
sa_prot_id = df.loc[df["Log2 Corrected Abundance Ratio"]>=alpha]["Accession"].to_list()
sa_prot_log2 = df.loc[df["Log2 Corrected Abundance Ratio"]>=alpha]["Log2 Corrected Abundance Ratio"].to_list()
sa_prot_pval = df.loc[df["Log2 Corrected Abundance Ratio"]>=alpha]["LOG10 Adj.P-val"].to_list()

# %%
bp_s = sorted(bp, key=lambda prot:prot[1])

# %%
fig4, ( (ax1, ax2), (ax3, ax4) ) = plt.subplots(figsize=(10,6), ncols=2, nrows=2)
